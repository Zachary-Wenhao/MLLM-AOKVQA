# %%
import json
import os
import random
from pprint import pprint
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import tarfile

# %%
with open(os.path.join('.','aokvqa', 'datasets', 'aokvqa', 'aokvqa_v1p0_train.json'), 'r') as file:
    data = json.load(file)

# %%
# data

# %%
difficult_q = [q for q in data if q['difficult_direct_answer'] == True]

# %%
q = random.choice(difficult_q)
pprint(q)

# tar_path = os.path.join(".", "aokvqa", "datasets", "eyJsaW5rIjogImZzOi8vYXNzZXRzLzIxNTFfQ09DTyAyMDE3L2NvY28tMjAxNy1EYXRhc2V0TmluamEudGFyIiwgInNpZyI6ICJwc05HeXpTY2xmZ1lIL1QzN0ZKUUVwc3VyVVFCaXN5WmpYTnZjOEtGK1RJPSJ9.tar")
# with tarfile.open(tar_path, 'r') as tar:
#     file = tar.extractfile('.txt')
#     if file:
#         content = file.read()
#         print(content.decode('utf-8'))  # Decode if it's a text file

# Path to the image
image_path = os.path.join('.','aokvqa', 'datasets', 'coco', 
                          "train2017", 'img', f"{str(q['image_id']).zfill(12)}.jpg")

# Load the image
image = mpimg.imread(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()
# Out:
# {'choices': ['cold weather', 'identifying themselves', 'hygiene', 'fashion'],
#  'correct_choice_idx': 2,
#  'difficult_direct_answer': True,
#  'direct_answers': ['germs',
#                     'hygiene',
#                     'sanitary use',
#                     'promote sanitation',
#                     'prevent sickness',
#                     'prevent covid',
#                     'safety',
#                     'handling food',
#                     'serving food',
#                     'to protect'],
#  'image_id': 243021,
#  'question': 'Why should they wear gloves?',
#  'question_id': 'GqyEfTu5h4pNFu5Gxnbt6W',
#  'rationales': ['These plastic gloves protect food from germs',
#                 'Germs can be passed when people touch surfaces.',
#                 'They want to be hygienic.'],
#  'split': 'train'}
